# %%
import cv2
import numpy as np 

image2=cv2.imread('7.jpg')
hsv = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
#cv2.imshow('HSV',hsv)

contours,hierarchy = cv2.findContours(hsv,cv2.RETR_EXTERNAL ,cv2.CHAIN_APPROX_NONE)
#cv2.drawContours(image2, contours, -1, (0,255,0), 3)
#cv2.imshow('Contours',image2)
print ("Number of contours = ", len(contours))

areas = [cv2.contourArea(c) for c in contours]

max_index = np.argmax(areas)
print('index: ', max_index)
cnt=contours[max_index]

epsilon = 0.05*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)
sides=approx.size

print('SIZE: ', sides)
x,y,w,h = cv2.boundingRect(cnt)
#rect=cv2.rectangle(image2,(x,y),(x+w,y+h),(0,255,0),2)
crop_img = image2[y:y+h, x:x+w]
output = cv2.cvtColor(crop_img, cv2.COLOR_BGR2GRAY)
print(output)
cv2.imshow('Rect', crop_img)
print ('Number of pixel in image: ',output.size)

pixel=cv2.countNonZero(output)
print('countNonZero:',pixel)
print('Ratio: ', (pixel/output.size))
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Number of contours =  47
# index:  28
# SIZE:  10
# [[150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]
#  [  0 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]
#  [  0   0 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]
#  [  0   0 150 150 150 150 150 150 150 150 150  52  62  68  70  70  67  60
#    52  44  39 150 150 150 150 150 150 150 150 150 150]
#  [  0 150 150 150 150 150 150 150 150 150  43  53  57  57  55 150  54  52
#    48  46  48  54 150  46 150 150 150 150 150 150 150]
#  [150 150 150 150 150 150 150 150 150  21  31  36 150 150 150 150 150  29
#    29  31  40  52  62  66  53 150 150 150 150 150 150]
#  [150 150 150 150 150 150 150 150   5  10  14 150 150 150 150 150 150 150
#     9  12  22  38  49  72  69  55 150 150 150 150 150]
#  [150 150 150 150 150 150 150   4   4   4 150 150 150 150 150 150 150 150
#   150   1  10  25  37  70  77  71  45 150 150 150 150]
#  [150 150 150 150  15  28  25  24  11 150 150 150 150 150 150 150 150 150
#   150 150   1  11  19  54  75  84  64 150 150 150 150]
#  [150 150 150 150 150  40  35  24  11 150 150 150 150 150 150 150 150 150
#   150 150   0   8  15  39  59  71  57 150 150 150 150]
#  [150 150 150 150 150  55  47  24  11 150 150 150 150 150   0 150 150 150
#   150 150   0   4   8  19  36  50  46 150 150 150 150]
#  [150 150 150 150 150  66  54  24  11 150 150 150 150 150   0 150 150 150
#   150 150   0   0   2   7  18  30  32 150 150 150 150]
#  [150 150 150 150 150  70  54  24  11 150 150 150 150 150   0 150 150 150
#   150 150   0   0   0   4   9  17  21 150 150 150 150]
#  [150 150 150 150  58  70  53  24  11 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150   4   7  13  18  14 150 150 150]
#  [150 150 150 150  57  71  54  24  11 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150   6  15  22  18 150 150 150]
#  [150 150 150 150  56  72  56  24  11 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150  18  28  22 150 150 150]
#  [150 150 150  26  55  67  62  33  13   0 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150  42  29 150 150 150]
#  [150 150 150 150  48  61  60  34  16   0 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150  52  50 150 150 150 150]
#  [150 150 150 150 150  51  54  37  20 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150  44  60  54 150 150 150 150]
#  [150 150 150 150 150 150  44  37  25  10 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150  44  56  46 150 150 150 150]
#  [150 150 150 150 150 150  32  34  27  15 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150  35  40 150 150 150 150 150]
#  [150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]
#  [150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]
#  [150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150 150
#   150 150 150 150 150 150 150 150 150 150 150 150 150]]
# Number of pixel in image:  744
# countNonZero: 726
# Ratio:  0.9758064516129032
